# %%
import torch
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
from torch.utils.data import DataLoader
import numpy as np

import warnings
warnings.filterwarnings("ignore")

from utils.datasets import AlphabetSortingDataset, NumberSortingDataset
from models.pointer_net import PointerNet
from torch.utils.data import DataLoader

# %%
params = {
    # Data
    'magnitude': 5,
    'batch_size': 128,
    'shuffle': True,
    'nof_workers': 0, # must stay at 0
    #Train
    'nof_epoch': 3,
    'lr': 0.001,
    # GPU
    'gpu': True,
    # Network
    'input_size': 300,
    'embedding_size': 300,
    'hiddens': 256,
    'nof_lstms': 2,
    'dropout': 0,
    'bidir': True
}

# %%
LEN = 10
#dataset = NumberSortingDataset(10**params['magnitude'], min_len=LEN, max_len=LEN)
#dataset = AlphabetSortingDataset(10**params['magnitude'], min_len=LEN, max_len=LEN, alphabet='0123456789')
dataset = AlphabetSortingDataset(10**params['magnitude'], min_len=LEN, max_len=LEN)
dataloader = DataLoader(dataset,
                        batch_size=params['batch_size'],
                        shuffle=params['shuffle'])

# %%
model = PointerNet(params['input_size'],
                   params['embedding_size'],
                   params['hiddens'],
                   params['nof_lstms'],
                   params['dropout'],
                   params['bidir'])

if params['gpu'] and torch.cuda.is_available():
    model.cuda()
    net = torch.nn.DataParallel(model, device_ids=range(torch.cuda.device_count()))
    cudnn.benchmark = True

CCE = torch.nn.CrossEntropyLoss()
model_optim = optim.Adam(filter(lambda p: p.requires_grad,
                                model.parameters()),
                                 lr=params['lr'])

# %%
from tqdm import tqdm
losses = []

model.train()
for i_epoch, epoch in enumerate(range(params['nof_epoch'])):
    batch_loss = []
    iterator = tqdm(dataloader, unit='Batch')
    
    for i_batch, sample_batched in enumerate(iterator):
        iterator.set_description('Epoch %i/%i' % (epoch+1, params['nof_epoch']))

        x, y, _ = sample_batched
        train_batch = Variable(x).float()
        target_batch = Variable(y)

        if torch.cuda.is_available():
            train_batch = train_batch.cuda()
            target_batch = target_batch.cuda()

        o, p = model(train_batch)
        o = o.contiguous().view(-1, o.size()[-1])
        target_batch = target_batch.view(-1)
        
        loss = CCE(o, target_batch) #/ target_batch.shape[1] # need to take the length of the table into account
        #acc = get_accuracy(p, target_batch)
        
        losses.append(loss.data)
        batch_loss.append(loss.data)

        model_optim.zero_grad()
        loss.backward()
        model_optim.step()
        
        iterator.set_postfix(loss='{}'.format(loss.data))
        
    # each epoch, reduce the learning rate
    for param in model_optim.param_groups:
            param['lr'] *= 0.95
            
    batch_loss = torch.Tensor(batch_loss)
    iterator.set_postfix(loss=np.average(batch_loss))
# Out:
# Epoch 1/3: 100%|██████████████████████████████████████████| 782/782 [01:49<00:00,  7.14Batch/s, loss=1.461153268814087]
# Epoch 2/3: 100%|██████████████████████████████████████████| 782/782 [01:49<00:00,  7.16Batch/s, loss=1.461151123046875]
# Epoch 3/3:  26%|███████████                               | 207/782 [00:28<01:21,  7.10Batch/s, loss=1.461151361465454]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-86118afdcaf0> in <module>
#      18             target_batch = target_batch.cuda()
#      19
# ---> 20         o, p = model(train_batch)
#      21         o = o.contiguous().view(-1, o.size()[-1])
#      22         target_batch = target_batch.view(-1)
#
# ~\AppData\Local\Continuum\anaconda3\envs\pointer_sort\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~\Development\VLDB\pointer_sort\models\pointer_net.py in forward(self, inputs)
#     310                                                            decoder_input0,
#     311                                                            decoder_hidden0,
# --> 312                                                            encoder_outputs)
#     313
#     314         return  outputs, pointers
#
# ~\AppData\Local\Continuum\anaconda3\envs\pointer_sort\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~\Development\VLDB\pointer_sort\models\pointer_net.py in forward(self, embedded_inputs, decoder_input, hidden, context)
#     221         # Recurrence loop
#     222         for _ in range(input_length):
# --> 223             h_t, c_t, outs = step(decoder_input, hidden)
#     224             hidden = (h_t, c_t)
#     225
#
# ~\Development\VLDB\pointer_sort\models\pointer_net.py in step(x, hidden)
#     214
#     215             # Attention section
# --> 216             hidden_t, output = self.att(h_t, context, torch.eq(mask, 0))
#     217             hidden_t = F.tanh(self.hidden_out(torch.cat((hidden_t, h_t), 1)))
#     218
#
# ~\AppData\Local\Continuum\anaconda3\envs\pointer_sort\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~\Development\VLDB\pointer_sort\models\pointer_net.py in forward(self, input, context, mask)
#     113
#     114         # (batch, hidden_dim, seq_len)
# --> 115         inp = self.input_linear(input).unsqueeze(2).expand(-1, -1, context.size(1))
#     116
#     117         # (batch, hidden_dim, seq_len)
#
# ~\AppData\Local\Continuum\anaconda3\envs\pointer_sort\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~\AppData\Local\Continuum\anaconda3\envs\pointer_sort\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\pointer_sort\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
model.eval()

num_samples = 100
x, y, z = dataset[:num_samples]
x = x.cuda().float()
y = y.cuda()

o, p = model(x)

y_pred = []
for pointers, values in zip(p, z):
    goal = []
    for point in pointers.cpu().numpy():
        goal.append(values[point])
    y_pred.append(goal)
    
y_true = []
for pointers, values in zip(y, z):
    goal = []
    for point in pointers.cpu().numpy():
        goal.append(values[point])
    y_true.append(goal)

# %%
correct = 0
for seq_pred, seq_true in zip(y_pred, y_true):
    correct += all([pred == true for (pred, true) in zip(seq_pred, seq_true)])
    print(seq_pred)
    print(seq_true)
    print("-" * 60)
acc = correct / num_samples
acc
# Out:
# ['a', 'b', 'c', 'g', 'm', 'q', 'r', 't', 'x', 'y']
# ['a', 'b', 'c', 'g', 'm', 'q', 'r', 't', 'x', 'y']
# ------------------------------------------------------------
# ['e', 'f', 'h', 'i', 'j', 'p', 'r', 's', 'x', 'y']
# ['e', 'f', 'h', 'i', 'j', 'p', 'r', 's', 'x', 'y']
# ------------------------------------------------------------
# ['c', 'e', 'f', 'i', 'k', 'o', 's', 'x', 'y', 'z']
# ['c', 'e', 'f', 'i', 'k', 'o', 's', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['g', 'j', 'm', 'n', 'q', 'r', 's', 'u', 'w', 'z']
# ['g', 'j', 'm', 'n', 'q', 'r', 's', 'u', 'w', 'z']
# ------------------------------------------------------------
# ['d', 'f', 'g', 'l', 'o', 'q', 'r', 's', 't', 'u']
# ['d', 'f', 'g', 'l', 'o', 'q', 'r', 's', 't', 'u']
# ------------------------------------------------------------
# ['b', 'f', 'h', 'm', 'o', 'q', 's', 'v', 'w', 'x']
# ['b', 'f', 'h', 'm', 'o', 'q', 's', 'v', 'w', 'x']
# ------------------------------------------------------------
# ['c', 'f', 'g', 'h', 'j', 'm', 'r', 's', 'u', 'x']
# ['c', 'f', 'g', 'h', 'j', 'm', 'r', 's', 'u', 'x']
# ------------------------------------------------------------
# ['e', 'g', 'h', 'j', 'k', 'l', 'n', 'p', 'u', 'y']
# ['e', 'g', 'h', 'j', 'k', 'l', 'n', 'p', 'u', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'g', 'q', 't', 'w', 'z']
# ['b', 'c', 'd', 'e', 'f', 'g', 'q', 't', 'w', 'z']
# ------------------------------------------------------------
# ['b', 'e', 'g', 'h', 'l', 'p', 'r', 's', 't', 'z']
# ['b', 'e', 'g', 'h', 'l', 'p', 'r', 's', 't', 'z']
# ------------------------------------------------------------
# ['a', 'b', 'c', 'h', 'i', 'm', 'q', 's', 't', 'v']
# ['a', 'b', 'c', 'h', 'i', 'm', 'q', 's', 't', 'v']
# ------------------------------------------------------------
# ['a', 'c', 'e', 'i', 'l', 'o', 'p', 't', 'u', 'x']
# ['a', 'c', 'e', 'i', 'l', 'o', 'p', 't', 'u', 'x']
# ------------------------------------------------------------
# ['e', 'f', 'g', 'h', 'l', 'm', 't', 'v', 'x', 'y']
# ['e', 'f', 'g', 'h', 'l', 'm', 't', 'v', 'x', 'y']
# ------------------------------------------------------------
# ['a', 'b', 'd', 'f', 'g', 'h', 'n', 'o', 's', 'v']
# ['a', 'b', 'd', 'f', 'g', 'h', 'n', 'o', 's', 'v']
# ------------------------------------------------------------
# ['d', 'f', 'g', 'h', 'j', 'n', 'o', 'u', 'v', 'w']
# ['d', 'f', 'g', 'h', 'j', 'n', 'o', 'u', 'v', 'w']
# ------------------------------------------------------------
# ['b', 'd', 'f', 'g', 'j', 'k', 'n', 'p', 'r', 'w']
# ['b', 'd', 'f', 'g', 'j', 'k', 'n', 'p', 'r', 'w']
# ------------------------------------------------------------
# ['d', 'f', 'g', 'i', 'k', 'n', 'q', 't', 'x', 'z']
# ['d', 'f', 'g', 'i', 'k', 'n', 'q', 't', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'f', 'h', 'j', 'o', 'q', 't', 'w']
# ['b', 'd', 'e', 'f', 'h', 'j', 'o', 'q', 't', 'w']
# ------------------------------------------------------------
# ['e', 'h', 'j', 'k', 'm', 's', 't', 'v', 'x', 'z']
# ['e', 'h', 'j', 'k', 'm', 's', 't', 'v', 'x', 'z']
# ------------------------------------------------------------
# ['a', 'b', 'f', 'i', 'l', 'p', 's', 'u', 'w', 'y']
# ['a', 'b', 'f', 'i', 'l', 'p', 's', 'u', 'w', 'y']
# ------------------------------------------------------------
# ['c', 'i', 'j', 'k', 'l', 'o', 'p', 'q', 'r', 'u']
# ['c', 'i', 'j', 'k', 'l', 'o', 'p', 'q', 'r', 'u']
# ------------------------------------------------------------
# ['a', 'b', 'e', 'g', 'l', 'r', 's', 't', 'w', 'z']
# ['a', 'b', 'e', 'g', 'l', 'r', 's', 't', 'w', 'z']
# ------------------------------------------------------------
# ['a', 'f', 'i', 'k', 'm', 'p', 'r', 't', 'u', 'w']
# ['a', 'f', 'i', 'k', 'm', 'p', 'r', 't', 'u', 'w']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'i', 'n', 'p', 'q', 'r', 'w']
# ['b', 'c', 'd', 'e', 'i', 'n', 'p', 'q', 'r', 'w']
# ------------------------------------------------------------
# ['c', 'd', 'g', 'i', 'j', 'l', 'r', 't', 'u', 'x']
# ['c', 'd', 'g', 'i', 'j', 'l', 'r', 't', 'u', 'x']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'h', 'i', 'k', 'l', 'm', 'q', 'z']
# ['b', 'd', 'e', 'h', 'i', 'k', 'l', 'm', 'q', 'z']
# ------------------------------------------------------------
# ['a', 'b', 'c', 'd', 'i', 'n', 'o', 'q', 'r', 'w']
# ['a', 'b', 'c', 'd', 'i', 'n', 'o', 'q', 'r', 'w']
# ------------------------------------------------------------
# ['b', 'j', 'l', 'm', 'o', 's', 't', 'u', 'x', 'y']
# ['b', 'j', 'l', 'm', 'o', 's', 't', 'u', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'g', 'n', 'q', 's', 't', 'w', 'x', 'y', 'z']
# ['b', 'g', 'n', 'q', 's', 't', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'm', 'o', 'p', 'r', 'u', 'v', 'w', 'z']
# ['b', 'd', 'm', 'o', 'p', 'r', 'u', 'v', 'w', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'j', 'k', 'q', 'r', 'v', 'w', 'x', 'y']
# ['b', 'c', 'j', 'k', 'q', 'r', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['a', 'b', 'f', 'g', 'h', 'j', 'o', 'q', 'r', 't']
# ['a', 'b', 'f', 'g', 'h', 'j', 'o', 'q', 'r', 't']
# ------------------------------------------------------------
# ['a', 'd', 'k', 'm', 'q', 't', 'u', 'v', 'w', 'y']
# ['a', 'd', 'k', 'm', 'q', 't', 'u', 'v', 'w', 'y']
# ------------------------------------------------------------
# ['d', 'e', 'm', 'n', 'q', 's', 't', 'v', 'x', 'z']
# ['d', 'e', 'm', 'n', 'q', 's', 't', 'v', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'e', 'g', 'j', 'o', 'q', 'r', 't', 'u', 'v']
# ['b', 'e', 'g', 'j', 'o', 'q', 'r', 't', 'u', 'v']
# ------------------------------------------------------------
# ['a', 'c', 'f', 'j', 'l', 'o', 's', 't', 'v', 'z']
# ['a', 'c', 'f', 'j', 'l', 'o', 's', 't', 'v', 'z']
# ------------------------------------------------------------
# ['d', 'e', 'h', 'j', 'm', 'q', 's', 'w', 'y', 'z']
# ['d', 'e', 'h', 'j', 'm', 'q', 's', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['e', 'f', 'j', 'k', 'o', 'q', 'u', 'v', 'w', 'y']
# ['e', 'f', 'j', 'k', 'o', 'q', 'u', 'v', 'w', 'y']
# ------------------------------------------------------------
# ['c', 'g', 'l', 'm', 'p', 'q', 's', 't', 'w', 'z']
# ['c', 'g', 'l', 'm', 'p', 'q', 's', 't', 'w', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'e', 'f', 'g', 'j', 'l', 't', 'v', 'y']
# ['b', 'c', 'e', 'f', 'g', 'j', 'l', 't', 'v', 'y']
# ------------------------------------------------------------
# ['e', 'i', 'j', 'k', 'n', 'p', 'q', 'r', 'u', 'v']
# ['e', 'i', 'j', 'k', 'n', 'p', 'q', 'r', 'u', 'v']
# ------------------------------------------------------------
# ['d', 'g', 'j', 'l', 'm', 's', 't', 'u', 'w', 'x']
# ['d', 'g', 'j', 'l', 'm', 's', 't', 'u', 'w', 'x']
# ------------------------------------------------------------
# ['e', 'g', 'i', 'k', 'l', 'o', 'r', 's', 'v', 'w']
# ['e', 'g', 'i', 'k', 'l', 'o', 'r', 's', 'v', 'w']
# ------------------------------------------------------------
# ['b', 'g', 'i', 'l', 'p', 'q', 'r', 's', 'u', 'z']
# ['b', 'g', 'i', 'l', 'p', 'q', 'r', 's', 'u', 'z']
# ------------------------------------------------------------
# ['a', 'd', 'f', 'i', 'l', 'n', 'p', 'q', 'v', 'x']
# ['a', 'd', 'f', 'i', 'l', 'n', 'p', 'q', 'v', 'x']
# ------------------------------------------------------------
# ['g', 'i', 'j', 'k', 'm', 'o', 't', 'u', 'w', 'z']
# ['g', 'i', 'j', 'k', 'm', 'o', 't', 'u', 'w', 'z']
# ------------------------------------------------------------
# ['a', 'b', 'd', 'e', 'f', 'g', 'i', 'm', 'x', 'y']
# ['a', 'b', 'd', 'e', 'f', 'g', 'i', 'm', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'g', 'l', 'o', 'p', 'v', 'w']
# ['b', 'c', 'd', 'e', 'g', 'l', 'o', 'p', 'v', 'w']
# ------------------------------------------------------------
# ['c', 'k', 'l', 'n', 'p', 's', 't', 'u', 'v', 'x']
# ['c', 'k', 'l', 'n', 'p', 's', 't', 'u', 'v', 'x']
# ------------------------------------------------------------
# ['a', 'c', 'f', 'i', 'l', 'm', 'o', 'r', 'u', 'y']
# ['a', 'c', 'f', 'i', 'l', 'm', 'o', 'r', 'u', 'y']
# ------------------------------------------------------------
# ['e', 'g', 'h', 'l', 'm', 'n', 'o', 'p', 's', 'y']
# ['e', 'g', 'h', 'l', 'm', 'n', 'o', 'p', 's', 'y']
# ------------------------------------------------------------
# ['b', 'e', 'h', 'j', 'p', 'q', 'u', 'v', 'w', 'z']
# ['b', 'e', 'h', 'j', 'p', 'q', 'u', 'v', 'w', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'h', 'i', 'l', 'o', 'q', 'r', 'w', 'x']
# ['b', 'c', 'h', 'i', 'l', 'o', 'q', 'r', 'w', 'x']
# ------------------------------------------------------------
# ['c', 'e', 'h', 'i', 'j', 'k', 'm', 't', 'u', 'z']
# ['c', 'e', 'h', 'i', 'j', 'k', 'm', 't', 'u', 'z']
# ------------------------------------------------------------
# ['e', 'f', 'h', 'j', 'k', 'l', 't', 'u', 'w', 'z']
# ['e', 'f', 'h', 'j', 'k', 'l', 't', 'u', 'w', 'z']
# ------------------------------------------------------------
# ['c', 'e', 'i', 'j', 'k', 'l', 'u', 'v', 'w', 'y']
# ['c', 'e', 'i', 'j', 'k', 'l', 'u', 'v', 'w', 'y']
# ------------------------------------------------------------
# ['d', 'f', 'h', 'r', 't', 'u', 'v', 'x', 'y', 'z']
# ['d', 'f', 'h', 'r', 't', 'u', 'v', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['f', 'm', 'n', 'o', 'p', 'q', 's', 'u', 'v', 'z']
# ['f', 'm', 'n', 'o', 'p', 'q', 's', 'u', 'v', 'z']
# ------------------------------------------------------------
# ['a', 'd', 'j', 'l', 'o', 'p', 'q', 'r', 'v', 'z']
# ['a', 'd', 'j', 'l', 'o', 'p', 'q', 'r', 'v', 'z']
# ------------------------------------------------------------
# ['a', 'c', 'd', 'e', 'g', 'k', 'l', 'n', 'q', 's']
# ['a', 'c', 'd', 'e', 'g', 'k', 'l', 'n', 'q', 's']
# ------------------------------------------------------------
# ['a', 'c', 'e', 'g', 'h', 'k', 'm', 'n', 'u', 'z']
# ['a', 'c', 'e', 'g', 'h', 'k', 'm', 'n', 'u', 'z']
# ------------------------------------------------------------
# ['a', 'c', 'e', 'g', 'i', 'l', 'm', 'n', 't', 'y']
# ['a', 'c', 'e', 'g', 'i', 'l', 'm', 'n', 't', 'y']
# ------------------------------------------------------------
# ['b', 'i', 'j', 'k', 'm', 'n', 'p', 'q', 'u', 'x']
# ['b', 'i', 'j', 'k', 'm', 'n', 'p', 'q', 'u', 'x']
# ------------------------------------------------------------
# ['d', 'f', 'h', 'i', 'm', 'n', 'o', 'r', 's', 'y']
# ['d', 'f', 'h', 'i', 'm', 'n', 'o', 'r', 's', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'e', 'f', 'g', 'h', 'i', 'm', 'o', 'v']
# ['b', 'c', 'e', 'f', 'g', 'h', 'i', 'm', 'o', 'v']
# ------------------------------------------------------------
# ['a', 'b', 'e', 'h', 'j', 'k', 'l', 'o', 'u', 'x']
# ['a', 'b', 'e', 'h', 'j', 'k', 'l', 'o', 'u', 'x']
# ------------------------------------------------------------
# ['a', 'b', 'd', 'f', 'i', 'l', 'n', 'v', 'x', 'y']
# ['a', 'b', 'd', 'f', 'i', 'l', 'n', 'v', 'x', 'y']
# ------------------------------------------------------------
# ['a', 'b', 'g', 'i', 'n', 'p', 't', 'u', 'x', 'y']
# ['a', 'b', 'g', 'i', 'n', 'p', 't', 'u', 'x', 'y']
# ------------------------------------------------------------
# ['a', 'd', 'h', 'i', 'n', 'r', 'v', 'w', 'y', 'z']
# ['a', 'd', 'h', 'i', 'n', 'r', 'v', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'f', 'g', 'i', 'k', 'p', 'r', 'v', 'x']
# ['b', 'd', 'f', 'g', 'i', 'k', 'p', 'r', 'v', 'x']
# ------------------------------------------------------------
# ['c', 'd', 'f', 'h', 'q', 'r', 't', 'u', 'x', 'z']
# ['c', 'd', 'f', 'h', 'q', 'r', 't', 'u', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'f', 'h', 'i', 'j', 'm', 'p', 'q', 't']
# ['b', 'd', 'f', 'h', 'i', 'j', 'm', 'p', 'q', 't']
# ------------------------------------------------------------
# ['a', 'b', 'c', 'e', 'g', 'h', 'l', 'p', 'q', 'r']
# ['a', 'b', 'c', 'e', 'g', 'h', 'l', 'p', 'q', 'r']
# ------------------------------------------------------------
# ['c', 'i', 'k', 'm', 'n', 'o', 'v', 'w', 'x', 'z']
# ['c', 'i', 'k', 'm', 'n', 'o', 'v', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['a', 'd', 'h', 'k', 'o', 'p', 'q', 't', 'y', 'z']
# ['a', 'd', 'h', 'k', 'o', 'p', 'q', 't', 'y', 'z']
# ------------------------------------------------------------
# ['h', 'i', 'j', 'k', 'm', 'o', 'p', 's', 't', 'v']
# ['h', 'i', 'j', 'k', 'm', 'o', 'p', 's', 't', 'v']
# ------------------------------------------------------------
# ['a', 'd', 'f', 'h', 'l', 'm', 'n', 'p', 'u', 'y']
# ['a', 'd', 'f', 'h', 'l', 'm', 'n', 'p', 'u', 'y']
# ------------------------------------------------------------
# ['d', 'f', 'h', 'j', 'l', 'm', 'p', 's', 'v', 'w']
# ['d', 'f', 'h', 'j', 'l', 'm', 'p', 's', 'v', 'w']
# ------------------------------------------------------------
# ['d', 'f', 'i', 'j', 'n', 'o', 'q', 't', 'u', 'z']
# ['d', 'f', 'i', 'j', 'n', 'o', 'q', 't', 'u', 'z']
# ------------------------------------------------------------
# ['b', 'h', 'j', 'm', 'o', 'p', 'q', 's', 'u', 'w']
# ['b', 'h', 'j', 'm', 'o', 'p', 'q', 's', 'u', 'w']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'k', 'm', 'n', 'r', 'u', 'v', 'y']
# ['b', 'd', 'e', 'k', 'm', 'n', 'r', 'u', 'v', 'y']
# ------------------------------------------------------------
# ['b', 'h', 'i', 'k', 'p', 'r', 't', 'w', 'x', 'z']
# ['b', 'h', 'i', 'k', 'p', 'r', 't', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['d', 'f', 'g', 'h', 'o', 'r', 's', 'u', 'v', 'x']
# ['d', 'f', 'g', 'h', 'o', 'r', 's', 'u', 'v', 'x']
# ------------------------------------------------------------
# ['d', 'f', 'h', 'i', 'm', 'n', 'o', 'q', 's', 'y']
# ['d', 'f', 'h', 'i', 'm', 'n', 'o', 'q', 's', 'y']
# ------------------------------------------------------------
# ['a', 'd', 'e', 'l', 'm', 'o', 'p', 'r', 't', 'z']
# ['a', 'd', 'e', 'l', 'm', 'o', 'p', 'r', 't', 'z']
# ------------------------------------------------------------
# ['b', 'e', 'g', 'h', 'i', 'k', 'l', 'q', 'u', 'w']
# ['b', 'e', 'g', 'h', 'i', 'k', 'l', 'q', 'u', 'w']
# ------------------------------------------------------------
# ['a', 'c', 'h', 'i', 'j', 'k', 'n', 'q', 'u', 'w']
# ['a', 'c', 'h', 'i', 'j', 'k', 'n', 'q', 'u', 'w']
# ------------------------------------------------------------
# ['d', 'f', 'h', 'i', 'j', 'q', 't', 'w', 'x', 'z']
# ['d', 'f', 'h', 'i', 'j', 'q', 't', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['d', 'l', 'm', 'n', 'o', 'q', 't', 'u', 'v', 'w']
# ['d', 'l', 'm', 'n', 'o', 'q', 't', 'u', 'v', 'w']
# ------------------------------------------------------------
# ['a', 'c', 'e', 'g', 'h', 'j', 'k', 'n', 'o', 'v']
# ['a', 'c', 'e', 'g', 'h', 'j', 'k', 'n', 'o', 'v']
# ------------------------------------------------------------
# ['a', 'c', 'f', 'j', 'k', 'm', 'q', 'r', 's', 'z']
# ['a', 'c', 'f', 'j', 'k', 'm', 'q', 'r', 's', 'z']
# ------------------------------------------------------------
# ['a', 'h', 'j', 'k', 'l', 'q', 'r', 's', 'u', 'v']
# ['a', 'h', 'j', 'k', 'l', 'q', 'r', 's', 'u', 'v']
# ------------------------------------------------------------
# ['b', 'e', 'f', 'g', 'k', 'l', 'n', 'r', 's', 'y']
# ['b', 'e', 'f', 'g', 'k', 'l', 'n', 'r', 's', 'y']
# ------------------------------------------------------------
# ['d', 'g', 'k', 'l', 'n', 'o', 'p', 'r', 't', 'w']
# ['d', 'g', 'k', 'l', 'n', 'o', 'p', 'r', 't', 'w']
# ------------------------------------------------------------
# ['c', 'e', 'h', 'j', 'm', 'n', 'o', 's', 'y', 'z']
# ['c', 'e', 'h', 'j', 'm', 'n', 'o', 's', 'y', 'z']
# ------------------------------------------------------------
# ['a', 'b', 'c', 'd', 'h', 'i', 'l', 'p', 'u', 'w']
# ['a', 'b', 'c', 'd', 'h', 'i', 'l', 'p', 'u', 'w']
# ------------------------------------------------------------
# ['b', 'l', 'p', 'q', 'r', 's', 't', 'v', 'x', 'y']
# ['b', 'l', 'p', 'q', 'r', 's', 't', 'v', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'h', 'j', 'k', 'l', 'n', 'o', 's', 'v']
# ['b', 'c', 'h', 'j', 'k', 'l', 'n', 'o', 's', 'v']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'k', 'm', 'p', 'q', 's', 'u', 'z']
# ['b', 'd', 'e', 'k', 'm', 'p', 'q', 's', 'u', 'z']
# ------------------------------------------------------------
# ['a', 'b', 'f', 'm', 'n', 'o', 'p', 's', 't', 'w']
# ['a', 'b', 'f', 'm', 'n', 'o', 'p', 's', 't', 'w']
# ------------------------------------------------------------
# 1.0
