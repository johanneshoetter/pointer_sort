# %%
import torch
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
from torch.utils.data import DataLoader
import numpy as np

import warnings
warnings.filterwarnings("ignore")

from utils.datasets import AlphabetSortingDataset, NumberSortingDataset
from models.pointer_net import PointerNet
from torch.utils.data import DataLoader

# %%
params = {
    # Data
    'magnitude': 3,
    'batch_size': 128,
    'shuffle': True,
    'nof_workers': 0, # must stay at 0
    #Train
    'nof_epoch': 3,
    'lr': 0.001,
    # GPU
    'gpu': True,
    # Network
    'input_size': 300,
    'embedding_size': 300,
    'hiddens': 256,
    'nof_lstms': 2,
    'dropout': 0,
    'bidir': True
}

# %%
LEN = 18
#dataset = NumberSortingDataset(10**params['magnitude'], min_len=LEN, max_len=LEN)
#dataset = AlphabetSortingDataset(10**params['magnitude'], min_len=LEN, max_len=LEN, alphabet='0123456789')
dataset = AlphabetSortingDataset(10**params['magnitude'], min_len=LEN, max_len=LEN)
dataloader = DataLoader(dataset,
                        batch_size=params['batch_size'],
                        shuffle=params['shuffle'])

# %%
model = PointerNet(params['input_size'],
                   params['embedding_size'],
                   params['hiddens'],
                   params['nof_lstms'],
                   params['dropout'],
                   params['bidir'])

if params['gpu'] and torch.cuda.is_available():
    model.cuda()
    net = torch.nn.DataParallel(model, device_ids=range(torch.cuda.device_count()))
    cudnn.benchmark = True

CCE = torch.nn.CrossEntropyLoss()
model_optim = optim.Adam(filter(lambda p: p.requires_grad,
                                model.parameters()),
                                 lr=params['lr'])

# %%
from tqdm import tqdm
losses = []

model.train()
for i_epoch, epoch in enumerate(range(params['nof_epoch'])):
    batch_loss = []
    iterator = tqdm(dataloader, unit='Batch')
    
    for i_batch, sample_batched in enumerate(iterator):
        iterator.set_description('Epoch %i/%i' % (epoch+1, params['nof_epoch']))

        x, y, _ = sample_batched
        train_batch = Variable(x).float()
        target_batch = Variable(y)

        if torch.cuda.is_available():
            train_batch = train_batch.cuda()
            target_batch = target_batch.cuda()

        o, p = model(train_batch)
        o = o.contiguous().view(-1, o.size()[-1])
        target_batch = target_batch.view(-1)
        
        loss = CCE(o, target_batch) #/ target_batch.shape[1] # need to take the length of the table into account
        #acc = get_accuracy(p, target_batch)
        
        losses.append(loss.data)
        batch_loss.append(loss.data)

        model_optim.zero_grad()
        loss.backward()
        model_optim.step()
        
        iterator.set_postfix(loss='{}'.format(loss.data))
        
    # each epoch, reduce the learning rate
    for param in model_optim.param_groups:
            param['lr'] *= 0.95
            
    batch_loss = torch.Tensor(batch_loss)
    iterator.set_postfix(loss=np.average(batch_loss))
# Out:
# Epoch 1/3: 100%|█████████████████████████████████████████| 782/782 [02:58<00:00,  4.37Batch/s, loss=2.5850460529327393]
# Epoch 2/3: 100%|█████████████████████████████████████████| 782/782 [02:57<00:00,  4.41Batch/s, loss=2.6493589878082275]
# Epoch 3/3: 100%|████████████████████████████████████████████| 782/782 [02:57<00:00,  4.41Batch/s, loss=2.5782470703125]

# %%
model.eval()

num_samples = 100
dataset = AlphabetSortingDataset(num_samples, min_len=LEN, max_len=LEN) 
x, y, z = dataset[:]
x = x.cuda().float()
y = y.cuda()

o, p = model(x)

y_pred = []
for pointers, values in zip(p, z):
    goal = []
    for point in pointers.cpu().numpy():
        goal.append(values[point])
    y_pred.append(goal)
    
y_true = []
for pointers, values in zip(y, z):
    goal = []
    for point in pointers.cpu().numpy():
        goal.append(values[point])
    y_true.append(goal)

# %%
correct = 0
for seq_pred, seq_true in zip(y_pred, y_true):
    correct += all([pred == true for (pred, true) in zip(seq_pred, seq_true)])
    print(seq_pred)
    print(seq_true)
    print("-" * 60)
acc = correct / num_samples
acc
# Out:
# ['b', 'e', 'f', 'g', 'i', 'j', 'k', 'l', 'n', 'p', 'q', 'r', 't', 'u', 'v', 'w', 'x', 'y']
# ['b', 'e', 'f', 'g', 'i', 'j', 'k', 'l', 'n', 'p', 'q', 'r', 't', 'u', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'n', 'p', 'q', 'r', 's', 'w', 'a', 'x', 'z']
# ['a', 'b', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'n', 'p', 'q', 'r', 's', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'p', 's', 'u', 'v', 'w', 'x']
# ['b', 'c', 'd', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'p', 's', 'u', 'v', 'w', 'x']
# ------------------------------------------------------------
# ['d', 'f', 'g', 'h', 'j', 'k', 'm', 'n', 'o', 'p', 'q', 's', 't', 'u', 'v', 'x', 'y', 'z']
# ['d', 'f', 'g', 'h', 'j', 'k', 'm', 'n', 'o', 'p', 'q', 's', 't', 'u', 'v', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'g', 'h', 'i', 'n', 'o', 'q', 'r', 't', 'u', 'v', 'w', 'a', 'x', 'y', 'z']
# ['a', 'b', 'd', 'e', 'g', 'h', 'i', 'n', 'o', 'q', 'r', 't', 'u', 'v', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'h', 'k', 'm', 'p', 'q', 'r', 's', 't', 'u', 'v', 'w', 'x', 'z']
# ['b', 'c', 'd', 'e', 'f', 'h', 'k', 'm', 'p', 'q', 'r', 's', 't', 'u', 'v', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'g', 'i', 'j', 'k', 'm', 'q', 'r', 's', 't', 'u', 'v', 'x', 'y']
# ['b', 'c', 'd', 'e', 'f', 'g', 'i', 'j', 'k', 'm', 'q', 'r', 's', 't', 'u', 'v', 'x', 'y']
# ------------------------------------------------------------
# ['c', 'd', 'e', 'f', 'h', 'i', 'j', 'l', 'q', 'r', 's', 't', 'u', 'w', 'a', 'x', 'y', 'z']
# ['a', 'c', 'd', 'e', 'f', 'h', 'i', 'j', 'l', 'q', 'r', 's', 't', 'u', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'f', 'j', 'k', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'w', 'x', 'y', 'z']
# ['b', 'd', 'e', 'f', 'j', 'k', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['c', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 's', 't', 'u', 'v', 'a', 'x', 'y']
# ['a', 'c', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 's', 't', 'u', 'v', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'f', 'g', 'h', 'i', 'j', 'k', 'm', 'n', 'o', 't', 'v', 'w', 'x', 'y', 'z']
# ['b', 'c', 'd', 'f', 'g', 'h', 'i', 'j', 'k', 'm', 'n', 'o', 't', 'v', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['d', 'e', 'f', 'k', 'l', 'm', 'o', 'p', 'q', 'r', 's', 't', 'u', 'v', 'w', 'a', 'x', 'y']
# ['a', 'd', 'e', 'f', 'k', 'l', 'm', 'o', 'p', 'q', 'r', 's', 't', 'u', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'g', 'j', 'l', 'm', 'p', 'q', 'r', 't', 'u', 'w', 'a', 'y', 'z']
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'j', 'l', 'm', 'p', 'q', 'r', 't', 'u', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'g', 'h', 'i', 'j', 'k', 'm', 'n', 'p', 'r', 's', 'u', 'v', 'w', 'y', 'z']
# ['b', 'c', 'd', 'g', 'h', 'i', 'j', 'k', 'm', 'n', 'p', 'r', 's', 'u', 'v', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'f', 'h', 'i', 'j', 'k', 'm', 'n', 'o', 'q', 'r', 's', 't', 'v', 'w', 'y', 'z']
# ['c', 'd', 'f', 'h', 'i', 'j', 'k', 'm', 'n', 'o', 'q', 'r', 's', 't', 'v', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['c', 'e', 'f', 'g', 'h', 'l', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'w', 'a', 'y', 'z']
# ['a', 'c', 'e', 'f', 'g', 'h', 'l', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['c', 'f', 'g', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 's', 't', 'v', 'w', 'a', 'x']
# ['a', 'c', 'f', 'g', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 's', 't', 'v', 'w', 'x']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'h', 'i', 'k', 'm', 'n', 'p', 'q', 't', 'u', 'w', 'a', 'x', 'z']
# ['a', 'b', 'c', 'd', 'e', 'f', 'h', 'i', 'k', 'm', 'n', 'p', 'q', 't', 'u', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'e', 'f', 'i', 'j', 'k', 'l', 'm', 'q', 'r', 's', 'u', 'v', 'w', 'a', 'x', 'z']
# ['a', 'b', 'c', 'e', 'f', 'i', 'j', 'k', 'l', 'm', 'q', 'r', 's', 'u', 'v', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'f', 'g', 'j', 'l', 'n', 'o', 'p', 'q', 'r', 's', 'u', 'v', 'w', 'a', 'x', 'y']
# ['a', 'b', 'd', 'f', 'g', 'j', 'l', 'n', 'o', 'p', 'q', 'r', 's', 'u', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'f', 'g', 'h', 'i', 'm', 'n', 'o', 'q', 'r', 't', 'u', 'w', 'x', 'y', 'z']
# ['b', 'd', 'e', 'f', 'g', 'h', 'i', 'm', 'n', 'o', 'q', 'r', 't', 'u', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'f', 'h', 'i', 'j', 'k', 'm', 'n', 'p', 'r', 's', 'u', 'w', 'x', 'y', 'z']
# ['b', 'c', 'd', 'f', 'h', 'i', 'j', 'k', 'm', 'n', 'p', 'r', 's', 'u', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'l', 'm', 'n', 't', 'v', 'w', 'a', 'x', 'y', 'z']
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'l', 'm', 'n', 't', 'v', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'e', 'f', 'i', 'j', 'k', 'l', 'o', 'r', 's', 't', 'u', 'v', 'w', 'a', 'y', 'z']
# ['a', 'b', 'c', 'e', 'f', 'i', 'j', 'k', 'l', 'o', 'r', 's', 't', 'u', 'v', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'e', 'f', 'i', 'j', 'l', 'm', 'n', 'p', 'q', 'r', 's', 't', 'u', 'w', 'a', 'y', 'z']
# ['a', 'b', 'e', 'f', 'i', 'j', 'l', 'm', 'n', 'p', 'q', 'r', 's', 't', 'u', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'g', 'h', 'i', 'j', 'p', 'q', 's', 't', 'v', 'w', 'a', 'x', 'y', 'z']
# ['a', 'b', 'c', 'd', 'e', 'g', 'h', 'i', 'j', 'p', 'q', 's', 't', 'v', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'g', 'i', 'j', 'k', 'l', 'n', 'o', 'p', 'r', 's', 'u', 'v', 'x', 'y', 'z']
# ['b', 'c', 'd', 'g', 'i', 'j', 'k', 'l', 'n', 'o', 'p', 'r', 's', 'u', 'v', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'g', 'h', 'j', 'k', 'n', 'p', 'q', 's', 't', 'u', 'w', 'a', 'z']
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'j', 'k', 'n', 'p', 'q', 's', 't', 'u', 'w', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'g', 'h', 'l', 'm', 'n', 'o', 's', 't', 'u', 'w', 'x', 'y', 'z']
# ['b', 'c', 'd', 'e', 'f', 'g', 'h', 'l', 'm', 'n', 'o', 's', 't', 'u', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'e', 'f', 'h', 'i', 'j', 'l', 'm', 'n', 'o', 'q', 't', 'u', 'v', 'a', 'x', 'y']
# ['a', 'b', 'c', 'e', 'f', 'h', 'i', 'j', 'l', 'm', 'n', 'o', 'q', 't', 'u', 'v', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'g', 'h', 'j', 'l', 'n', 'p', 'q', 'r', 't', 'u', 'w', 'a', 'x', 'y', 'z']
# ['a', 'b', 'd', 'e', 'g', 'h', 'j', 'l', 'n', 'p', 'q', 'r', 't', 'u', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'g', 'i', 'j', 'k', 'l', 'n', 'p', 'q', 's', 'u', 'w', 'a', 'x', 'y', 'z']
# ['a', 'b', 'd', 'e', 'g', 'i', 'j', 'k', 'l', 'n', 'p', 'q', 's', 'u', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'f', 'h', 'i', 'j', 'l', 'm', 'n', 'o', 'r', 's', 't', 'u', 'v', 'w', 'x', 'y']
# ['c', 'd', 'f', 'h', 'i', 'j', 'l', 'm', 'n', 'o', 'r', 's', 't', 'u', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['c', 'd', 'h', 'i', 'j', 'l', 'n', 'o', 'p', 'q', 'r', 's', 'u', 'v', 'w', 'a', 'x', 'y']
# ['a', 'c', 'd', 'h', 'i', 'j', 'l', 'n', 'o', 'p', 'q', 'r', 's', 'u', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['c', 'd', 'f', 'h', 'i', 'j', 'k', 'm', 'o', 'p', 'q', 'r', 's', 'u', 'v', 'w', 'y', 'z']
# ['c', 'd', 'f', 'h', 'i', 'j', 'k', 'm', 'o', 'p', 'q', 'r', 's', 'u', 'v', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'f', 'g', 'i', 'j', 'm', 'n', 'o', 'p', 'q', 'u', 'v', 'w', 'a', 'y', 'z']
# ['a', 'b', 'c', 'd', 'f', 'g', 'i', 'j', 'm', 'n', 'o', 'p', 'q', 'u', 'v', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'f', 'h', 'i', 'j', 'k', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't', 'v', 'x', 'z']
# ['c', 'd', 'f', 'h', 'i', 'j', 'k', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't', 'v', 'x', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'm', 'n', 'o', 'q', 'r', 's', 't', 'u', 'w', 'z']
# ['c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'm', 'n', 'o', 'q', 'r', 's', 't', 'u', 'w', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'e', 'g', 'i', 'k', 'l', 'm', 'q', 'r', 's', 't', 'u', 'v', 'w', 'a', 'x', 'y']
# ['a', 'b', 'c', 'e', 'g', 'i', 'k', 'l', 'm', 'q', 'r', 's', 't', 'u', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'e', 'f', 'g', 'h', 'j', 'k', 'n', 'o', 'p', 'q', 'r', 's', 't', 'v', 'w', 'x', 'z']
# ['b', 'e', 'f', 'g', 'h', 'j', 'k', 'n', 'o', 'p', 'q', 'r', 's', 't', 'v', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'f', 'g', 'h', 'i', 'j', 'k', 'n', 'o', 'p', 'q', 'r', 't', 'u', 'a', 'x', 'z']
# ['a', 'b', 'd', 'f', 'g', 'h', 'i', 'j', 'k', 'n', 'o', 'p', 'q', 'r', 't', 'u', 'x', 'z']
# ------------------------------------------------------------
# ['c', 'f', 'g', 'i', 'j', 'k', 'l', 'n', 'o', 'p', 'q', 's', 't', 'v', 'w', 'a', 'y', 'z']
# ['a', 'c', 'f', 'g', 'i', 'j', 'k', 'l', 'n', 'o', 'p', 'q', 's', 't', 'v', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'e', 'f', 'g', 'h', 'i', 'j', 'n', 'o', 'p', 's', 'u', 'v', 'w', 'x', 'y', 'z']
# ['b', 'c', 'e', 'f', 'g', 'h', 'i', 'j', 'n', 'o', 'p', 's', 'u', 'v', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'f', 'g', 'h', 'j', 'k', 'l', 'm', 'n', 'p', 'r', 'v', 'w', 'a', 'x', 'y']
# ['a', 'b', 'd', 'e', 'f', 'g', 'h', 'j', 'k', 'l', 'm', 'n', 'p', 'r', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'p', 'q', 't', 'u', 'v', 'w', 'x', 'y']
# ['b', 'c', 'd', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'p', 'q', 't', 'u', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'd', 'f', 'g', 'h', 'j', 'l', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'w', 'y', 'z']
# ['b', 'd', 'f', 'g', 'h', 'j', 'l', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'f', 'i', 'k', 'm', 'n', 'p', 'q', 'r', 's', 't', 'u', 'a', 'x', 'y', 'z']
# ['a', 'b', 'c', 'd', 'f', 'i', 'k', 'm', 'n', 'p', 'q', 'r', 's', 't', 'u', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'f', 'g', 'h', 'j', 'k', 'l', 'm', 'o', 'q', 'r', 't', 'u', 'v', 'w', 'a', 'z']
# ['a', 'b', 'd', 'f', 'g', 'h', 'j', 'k', 'l', 'm', 'o', 'q', 'r', 't', 'u', 'v', 'w', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'e', 'f', 'g', 'h', 'i', 'm', 'n', 'o', 'p', 'q', 'r', 'u', 'v', 'a', 'x', 'z']
# ['a', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'm', 'n', 'o', 'p', 'q', 'r', 'u', 'v', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'f', 'g', 'l', 'm', 'n', 'o', 'p', 's', 't', 'u', 'v', 'w', 'a', 'x', 'y']
# ['a', 'b', 'd', 'e', 'f', 'g', 'l', 'm', 'n', 'o', 'p', 's', 't', 'u', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'g', 'h', 'i', 'l', 'm', 'o', 'r', 's', 't', 'v', 'w', 'a', 'y', 'z']
# ['a', 'b', 'c', 'd', 'e', 'g', 'h', 'i', 'l', 'm', 'o', 'r', 's', 't', 'v', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'e', 'g', 'h', 'i', 'k', 'l', 'm', 'o', 'p', 'r', 't', 'v', 'w', 'a', 'x', 'z']
# ['a', 'c', 'd', 'e', 'g', 'h', 'i', 'k', 'l', 'm', 'o', 'p', 'r', 't', 'v', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'o', 'q', 't', 'u', 'v', 'w', 'x', 'y', 'z']
# ['b', 'c', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'o', 'q', 't', 'u', 'v', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'f', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 'r', 'w', 'a', 'x', 'y']
# ['a', 'b', 'c', 'd', 'f', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 'r', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['c', 'e', 'f', 'g', 'h', 'i', 'm', 'n', 'o', 'p', 'q', 's', 't', 'u', 'v', 'w', 'x', 'y']
# ['c', 'e', 'f', 'g', 'h', 'i', 'm', 'n', 'o', 'p', 'q', 's', 't', 'u', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['d', 'e', 'g', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'r', 's', 't', 'v', 'w', 'a', 'x', 'y']
# ['a', 'd', 'e', 'g', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'r', 's', 't', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'f', 'g', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 'r', 't', 'w', 'a', 'x']
# ['a', 'b', 'c', 'd', 'f', 'g', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 'r', 't', 'w', 'x']
# ------------------------------------------------------------
# ['d', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'm', 'p', 'q', 'r', 's', 't', 'v', 'w', 'x', 'z']
# ['d', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'm', 'p', 'q', 'r', 's', 't', 'v', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'g', 'h', 'i', 'j', 'k', 'o', 'p', 'q', 'r', 's', 't', 'u', 'a', 'x', 'y', 'z']
# ['a', 'c', 'd', 'g', 'h', 'i', 'j', 'k', 'o', 'p', 'q', 'r', 's', 't', 'u', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'f', 'h', 'i', 'j', 'l', 'p', 'q', 'r', 's', 't', 'u', 'v', 'w', 'a', 'x', 'y', 'z']
# ['a', 'b', 'f', 'h', 'i', 'j', 'l', 'p', 'q', 'r', 's', 't', 'u', 'v', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'e', 'f', 'g', 'm', 'n', 'o', 'p', 'r', 's', 't', 'u', 'v', 'w', 'x', 'y', 'z']
# ['c', 'd', 'e', 'f', 'g', 'm', 'n', 'o', 'p', 'r', 's', 't', 'u', 'v', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['e', 'f', 'g', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 't', 'u', 'v', 'w', 'a', 'x', 'y', 'z']
# ['a', 'e', 'f', 'g', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 't', 'u', 'v', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'i', 'j', 'k', 'l', 'm', 'o', 'q', 'r', 'u', 'v', 'w', 'y', 'z']
# ['b', 'c', 'd', 'e', 'f', 'i', 'j', 'k', 'l', 'm', 'o', 'q', 'r', 'u', 'v', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'e', 'f', 'g', 'k', 'l', 'm', 'n', 'o', 'q', 's', 't', 'u', 'v', 'w', 'a', 'x']
# ['a', 'c', 'd', 'e', 'f', 'g', 'k', 'l', 'm', 'n', 'o', 'q', 's', 't', 'u', 'v', 'w', 'x']
# ------------------------------------------------------------
# ['c', 'd', 'f', 'h', 'i', 'l', 'm', 'n', 'o', 'r', 's', 't', 'u', 'w', 'a', 'x', 'y', 'z']
# ['a', 'c', 'd', 'f', 'h', 'i', 'l', 'm', 'n', 'o', 'r', 's', 't', 'u', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'g', 'h', 'i', 'j', 'k', 'n', 'o', 'p', 'r', 's', 't', 'u', 'v', 'a', 'x', 'y']
# ['a', 'b', 'd', 'g', 'h', 'i', 'j', 'k', 'n', 'o', 'p', 'r', 's', 't', 'u', 'v', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'h', 'i', 'j', 'm', 'n', 'q', 'r', 's', 'u', 'w', 'a', 'x', 'z']
# ['a', 'b', 'c', 'd', 'e', 'f', 'h', 'i', 'j', 'm', 'n', 'q', 'r', 's', 'u', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'e', 'f', 'g', 'i', 'j', 'l', 'm', 'n', 'p', 'q', 's', 'u', 'v', 'w', 'a', 'x', 'y']
# ['a', 'b', 'e', 'f', 'g', 'i', 'j', 'l', 'm', 'n', 'p', 'q', 's', 'u', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'f', 'g', 'h', 'k', 'l', 'm', 'o', 'p', 'q', 'r', 'u', 'a', 'x', 'y', 'z']
# ['a', 'b', 'c', 'd', 'f', 'g', 'h', 'k', 'l', 'm', 'o', 'p', 'q', 'r', 'u', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'p', 'q', 'r', 's', 't', 'w', 'x', 'z']
# ['b', 'c', 'd', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'p', 'q', 'r', 's', 't', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'f', 'g', 'h', 'i', 'j', 'k', 'm', 'n', 'o', 'q', 'r', 's', 'u', 'w', 'a', 'x', 'z']
# ['a', 'b', 'f', 'g', 'h', 'i', 'j', 'k', 'm', 'n', 'o', 'q', 'r', 's', 'u', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'e', 'f', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't', 'v', 'a', 'x']
# ['a', 'c', 'd', 'e', 'f', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't', 'v', 'x']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'g', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 's', 'u', 'v', 'a', 'x', 'y']
# ['a', 'b', 'c', 'd', 'g', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 's', 'u', 'v', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'm', 'n', 'o', 'p', 'r', 'u', 'w', 'a', 'z']
# ['a', 'b', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'm', 'n', 'o', 'p', 'r', 'u', 'w', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'f', 'g', 'h', 'j', 'm', 'n', 'o', 'q', 's', 't', 'u', 'v', 'a', 'x', 'y', 'z']
# ['a', 'c', 'd', 'f', 'g', 'h', 'j', 'm', 'n', 'o', 'q', 's', 't', 'u', 'v', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'g', 'j', 'k', 'l', 'n', 'o', 'q', 'r', 's', 't', 'w', 'a', 'y', 'z']
# ['a', 'b', 'c', 'd', 'e', 'g', 'j', 'k', 'l', 'n', 'o', 'q', 'r', 's', 't', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'e', 'f', 'g', 'h', 'j', 'l', 'm', 'o', 'p', 'q', 'r', 't', 'u', 'v', 'w', 'a', 'x']
# ['a', 'b', 'e', 'f', 'g', 'h', 'j', 'l', 'm', 'o', 'p', 'q', 'r', 't', 'u', 'v', 'w', 'x']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'f', 'g', 'i', 'j', 'l', 'm', 'o', 'p', 'q', 's', 't', 'v', 'w', 'a', 'x']
# ['a', 'b', 'd', 'e', 'f', 'g', 'i', 'j', 'l', 'm', 'o', 'p', 'q', 's', 't', 'v', 'w', 'x']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 's', 't', 'u', 'v', 'w', 'a', 'z']
# ['a', 'b', 'c', 'd', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 's', 't', 'u', 'v', 'w', 'z']
# ------------------------------------------------------------
# ['d', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 'u', 'v', 'w', 'x', 'y', 'z']
# ['d', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 'u', 'v', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'g', 'i', 'm', 'o', 'p', 'q', 'r', 's', 't', 'v', 'a', 'y', 'z']
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'i', 'm', 'o', 'p', 'q', 'r', 's', 't', 'v', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'g', 'h', 'j', 'k', 'l', 'm', 'o', 'q', 'r', 's', 't', 'w', 'a', 'y', 'z']
# ['a', 'b', 'c', 'd', 'g', 'h', 'j', 'k', 'l', 'm', 'o', 'q', 'r', 's', 't', 'w', 'y', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'e', 'f', 'g', 'm', 'n', 'p', 'q', 'r', 's', 'u', 'v', 'w', 'a', 'x', 'y', 'z']
# ['a', 'c', 'd', 'e', 'f', 'g', 'm', 'n', 'p', 'q', 'r', 's', 'u', 'v', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'e', 'f', 'g', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 's', 't', 'w', 'x', 'z']
# ['c', 'd', 'e', 'f', 'g', 'j', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 's', 't', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'f', 'g', 'h', 'i', 'k', 'l', 'n', 'o', 'p', 'q', 'u', 'a', 'x', 'y', 'z']
# ['a', 'b', 'c', 'd', 'f', 'g', 'h', 'i', 'k', 'l', 'n', 'o', 'p', 'q', 'u', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'f', 'h', 'k', 'm', 'n', 'o', 'p', 'q', 'r', 's', 'u', 'v', 'w', 'a', 'x', 'z']
# ['a', 'b', 'd', 'f', 'h', 'k', 'm', 'n', 'o', 'p', 'q', 'r', 's', 'u', 'v', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'e', 'f', 'h', 'i', 'k', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'x', 'z']
# ['b', 'c', 'e', 'f', 'h', 'i', 'k', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'x', 'z']
# ------------------------------------------------------------
# ['c', 'd', 'f', 'g', 'h', 'j', 'k', 'l', 'm', 'n', 'o', 'r', 's', 't', 'v', 'w', 'x', 'z']
# ['c', 'd', 'f', 'g', 'h', 'j', 'k', 'l', 'm', 'n', 'o', 'r', 's', 't', 'v', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['c', 'f', 'g', 'h', 'j', 'k', 'l', 'm', 'o', 'p', 'q', 's', 't', 'w', 'a', 'x', 'y', 'z']
# ['a', 'c', 'f', 'g', 'h', 'j', 'k', 'l', 'm', 'o', 'p', 'q', 's', 't', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'e', 'f', 'g', 'h', 'i', 'l', 'm', 'n', 'o', 'q', 's', 't', 'u', 'w', 'x', 'y', 'z']
# ['b', 'e', 'f', 'g', 'h', 'i', 'l', 'm', 'n', 'o', 'q', 's', 't', 'u', 'w', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'g', 'h', 'k', 'l', 'n', 'o', 'q', 'r', 's', 'u', 'v', 'x', 'y', 'z']
# ['b', 'c', 'd', 'e', 'g', 'h', 'k', 'l', 'n', 'o', 'q', 'r', 's', 'u', 'v', 'x', 'y', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'g', 'h', 'j', 'k', 'l', 'm', 'n', 'o', 'q', 'r', 's', 't', 'u', 'v', 'w', 'x']
# ['b', 'd', 'g', 'h', 'j', 'k', 'l', 'm', 'n', 'o', 'q', 'r', 's', 't', 'u', 'v', 'w', 'x']
# ------------------------------------------------------------
# ['b', 'c', 'e', 'f', 'g', 'j', 'l', 'm', 'n', 'p', 'q', 's', 't', 'u', 'v', 'w', 'a', 'z']
# ['a', 'b', 'c', 'e', 'f', 'g', 'j', 'l', 'm', 'n', 'p', 'q', 's', 't', 'u', 'v', 'w', 'z']
# ------------------------------------------------------------
# ['d', 'e', 'f', 'h', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'r', 's', 'u', 'v', 'a', 'x', 'y']
# ['a', 'd', 'e', 'f', 'h', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'r', 's', 'u', 'v', 'x', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'g', 'h', 'l', 'n', 'o', 'p', 'q', 'r', 's', 't', 'v', 'w', 'x', 'y']
# ['b', 'c', 'd', 'e', 'g', 'h', 'l', 'n', 'o', 'p', 'q', 'r', 's', 't', 'v', 'w', 'x', 'y']
# ------------------------------------------------------------
# ['d', 'e', 'f', 'g', 'i', 'j', 'k', 'l', 'm', 'o', 'q', 'r', 't', 'u', 'v', 'w', 'x', 'z']
# ['d', 'e', 'f', 'g', 'i', 'j', 'k', 'l', 'm', 'o', 'q', 'r', 't', 'u', 'v', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'h', 'i', 'j', 'l', 'm', 'n', 'p', 'q', 'r', 't', 'u', 'v', 'w', 'y']
# ['b', 'c', 'd', 'e', 'h', 'i', 'j', 'l', 'm', 'n', 'p', 'q', 'r', 't', 'u', 'v', 'w', 'y']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'h', 'j', 'n', 'o', 'p', 'q', 's', 't', 'u', 'v', 'w', 'x', 'z']
# ['b', 'c', 'd', 'e', 'f', 'h', 'j', 'n', 'o', 'p', 'q', 's', 't', 'u', 'v', 'w', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'c', 'd', 'e', 'f', 'i', 'k', 'l', 'm', 'n', 'o', 'q', 'r', 's', 't', 'a', 'x', 'z']
# ['a', 'b', 'c', 'd', 'e', 'f', 'i', 'k', 'l', 'm', 'n', 'o', 'q', 'r', 's', 't', 'x', 'z']
# ------------------------------------------------------------
# ['b', 'd', 'e', 'f', 'i', 'l', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'w', 'a', 'x', 'z']
# ['a', 'b', 'd', 'e', 'f', 'i', 'l', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'w', 'x', 'z']
# ------------------------------------------------------------
# 0.38

# %%
model.serialize('serialized/pointer_net.pt')

# %%
model.initialize('serialized/pointer_net.pt')
