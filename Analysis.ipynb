# %% [markdown]
# Note: read without environment activated, as the environment for pointer sort has no matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
log_df = pd.read_csv('logging/schema_pointer.txt')
log_df.head()
# Out:
#    epoch  train_acc  test_acc
# 0      1   0.216967  0.337763
# 1      2   0.347856  0.418355
# 2      3   0.495284  0.536414
# 3      4   0.572494  0.642961
# 4      5   0.638232  0.643980

# %% [markdown]
# **TODO**: Logs ohne Transferlernen

# %%
plt.figure(figsize=(10,10))
x = log_df['epoch'].values
y = log_df['train_acc'].values * 100
plt.plot(x,y, label='train')
y = log_df['test_acc'].values * 100
plt.plot(x,y, label='test')
plt.ylabel('Accuracy (in %)')
plt.xlabel('Epoch')
plt.title('Performance of SchemaPointer')
plt.legend()
plt.savefig('figures/schema_pointer_tl.jpg', bbox_inches = 'tight')
plt.show();
